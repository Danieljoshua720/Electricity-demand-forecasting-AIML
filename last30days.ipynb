# %% [markdown]
# <a href="https://colab.research.google.com/github/Danieljoshua720/Electricity-demand-forecasting-AIML/blob/main/last30days.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/powerdemand_5min_2021_to_2024_with weather.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             datetime  Power demand  temp  dwpt  rhum  wdir  \
# 0           0  2021-01-01 00:30:00       2014.00   8.0   6.9  93.0   0.0
# 1           1  2021-01-01 00:35:00       2005.63   8.0   6.9  93.0   0.0
# 2           2  2021-01-01 00:40:00       1977.60   8.0   6.9  93.0   0.0
# 3           3  2021-01-01 00:45:00       1976.44   8.0   6.9  93.0   0.0
# 4           4  2021-01-01 00:50:00       1954.37   8.0   6.9  93.0   0.0
#
#    wspd    pres  year  month  day  hour  minute  moving_avg_3
# 0   0.0  1017.0  2021      1    1     0      30           NaN
# 1   0.0  1017.0  2021      1    1     0      35           NaN
# 2   0.0  1017.0  2021      1    1     0      40   1999.076667
# 3   0.0  1017.0  2021      1    1     0      45   1986.556667
# 4   0.0  1017.0  2021      1    1     0      50   1969.470000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# datetime          0
# Power demand      0
# temp              0
# dwpt              0
# rhum              0
# wdir            540
# wspd              0
# pres              0
# year              0
# month             0
# day               0
# hour              0
# minute            0
# moving_avg_3      2
# dtype: int64

# %%
df.dropna()
# Out:
#         Unnamed: 0             datetime  Power demand  temp  dwpt  rhum  \
# 2                2  2021-01-01 00:40:00       1977.60   8.0   6.9  93.0
# 3                3  2021-01-01 00:45:00       1976.44   8.0   6.9  93.0
# 4                4  2021-01-01 00:50:00       1954.37   8.0   6.9  93.0
# 5                5  2021-01-01 00:55:00       1925.21   8.0   6.9  93.0
# 6                6  2021-01-01 01:00:00       1907.98   8.0   6.9  93.0
# ...            ...                  ...           ...   ...   ...   ...
# 393435      393435  2024-12-12 00:10:00       2146.84  12.3   6.8  69.0
# 393436      393436  2024-12-12 00:15:00       2116.66  12.3   6.8  69.0
# 393437      393437  2024-12-12 00:20:00       2082.77  12.3   6.8  69.0
# 393438      393438  2024-12-12 00:25:00       2059.17  12.3   6.8  69.0
# 393439      393439  2024-12-12 00:30:00       2049.66  12.3   6.8  69.0
#
#          wdir  wspd    pres  year  month  day  hour  minute  moving_avg_3
# ...

# %%
df.drop_duplicates()
# Out:
#         Unnamed: 0             datetime  Power demand  temp  dwpt  rhum  \
# 0                0  2021-01-01 00:30:00       2014.00   8.0   6.9  93.0
# 1                1  2021-01-01 00:35:00       2005.63   8.0   6.9  93.0
# 2                2  2021-01-01 00:40:00       1977.60   8.0   6.9  93.0
# 3                3  2021-01-01 00:45:00       1976.44   8.0   6.9  93.0
# 4                4  2021-01-01 00:50:00       1954.37   8.0   6.9  93.0
# ...            ...                  ...           ...   ...   ...   ...
# 393435      393435  2024-12-12 00:10:00       2146.84  12.3   6.8  69.0
# 393436      393436  2024-12-12 00:15:00       2116.66  12.3   6.8  69.0
# 393437      393437  2024-12-12 00:20:00       2082.77  12.3   6.8  69.0
# 393438      393438  2024-12-12 00:25:00       2059.17  12.3   6.8  69.0
# 393439      393439  2024-12-12 00:30:00       2049.66  12.3   6.8  69.0
#
#          wdir  wspd    pres  year  month  day  hour  minute  moving_avg_3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393440 entries, 0 to 393439
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    393440 non-null  int64
#  1   datetime      393440 non-null  object
#  2   Power demand  393440 non-null  float64
#  3   temp          393440 non-null  float64
#  4   dwpt          393440 non-null  float64
#  5   rhum          393440 non-null  float64
#  6   wdir          392900 non-null  float64
#  7   wspd          393440 non-null  float64
#  8   pres          393440 non-null  float64
#  9   year          393440 non-null  int64
#  10  month         393440 non-null  int64
#  11  day           393440 non-null  int64
#  12  hour          393440 non-null  int64
#  13  minute        393440 non-null  int64
#  14  moving_avg_3  393438 non-null  float64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 45.0+ MB

# %%
# Convert datetime
df['datetime'] = pd.to_datetime(df['datetime'])

# Sort by time (VERY IMPORTANT)
df = df.sort_values('datetime').reset_index(drop=True)

# Keep ONLY target column for now (avoid scaler mistakes)
data = df[['Power demand']].values

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
n_past = 168        # 7 days history
n_future = 720      # last 30 days (hourly)

# %%
train_data = data_scaled[:-n_future]
test_data  = data_scaled[-n_future:]

# %%
X_train, y_train = [], []

for i in range(n_past, len(train_data)):
    X_train.append(train_data[i-n_past:i])
    y_train.append(train_data[i])

X_train = np.array(X_train)
y_train = np.array(y_train)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (392552, 168, 1)
# y_train shape: (392552, 1)

# %%
model = Sequential([
    LSTM(64, input_shape=(n_past, 1)),
    Dense(1)
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse'
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_7 (LSTM)                   │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 47s 8ms/step - loss: 0.0023 - val_loss: 1.0191e-04
# Epoch 2/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 45s 8ms/step - loss: 9.8009e-05 - val_loss: 9.0111e-05
# Epoch 3/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 1.0777e-04 - val_loss: 8.9533e-05
# Epoch 4/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 45s 8ms/step - loss: 1.0136e-04 - val_loss: 9.2347e-05
# Epoch 5/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 1.0124e-04 - val_loss: 9.3502e-05
# Epoch 6/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 8.5921e-05 - val_loss: 8.8950e-05
# Epoch 7/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 9.9638e-05 - val_loss: 9.0427e-05
# Epoch 8/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 45s 8ms/step - loss: 9.6077e-05 - val_loss: 9.5173e-05
# Epoch 9/10
# 5521/5521 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 9.3559e-05 - val_loss: 8.8811e-05
# Epoch 10/10
# ...

# %%
X_test = []

start = len(data_scaled) - n_future - n_past
end   = len(data_scaled) - n_past

for i in range(start, end):
    X_test.append(data_scaled[i:i+n_past])

X_test = np.array(X_test)

# %%
X_test.shape
# Out:
# (720, 168, 1)

# %%
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
y_true = scaler.inverse_transform(
    data_scaled[-n_future:]
)

# %%
hours = np.arange(1, n_future + 1)

plt.figure(figsize=(14,5))
plt.plot(hours, y_true, label='Actual Last 30 Days', color='green')
plt.plot(hours, y_pred, label='Predicted Last 30 Days', color='red')
plt.xlabel('Hours (Last 30 Days)')
plt.ylabel('Power Demand')
plt.title('Actual vs Predicted – Last 30 Days')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

MAE  = mean_absolute_error(y_true, y_pred)
MSE  = mean_squared_error(y_true, y_pred)
RMSE = np.sqrt(MSE)
R2   = r2_score(y_true, y_pred)

print("MAE  :", MAE)
print("MSE  :", MSE)
print("RMSE :", RMSE)
print("R²   :", R2)
# Out:
# MAE  : 27.598500345865876
# MSE  : 3720.384129453028
# RMSE : 60.99495167186402
# R²   : 0.9915543044757751

# %%
import matplotlib.pyplot as plt
import numpy as np

# X axis
hours = np.arange(len(y_true))

# ===== SELECT ZOOM REGION (CHANGE THESE) =====
zoom_start = 460
zoom_end   = 520

# ===== FIGURE WITH 2 PANELS =====
fig = plt.figure(figsize=(14,5))

# -------- LEFT: FULL PLOT --------
ax1 = plt.subplot(1,2,1)

ax1.plot(hours, y_true, 'g-', label='Actual')
ax1.plot(hours, y_pred, 'r-', label='Predicted')

ax1.set_xlabel('Hours (Last 30 Days)')
ax1.set_ylabel('Power Demand')
ax1.set_title('Actual vs Predicted (Full Range)')
ax1.legend()
ax1.grid(True)

# Highlight zoom area
ax1.axvspan(zoom_start, zoom_end, color='gray', alpha=0.3)

# -------- RIGHT: ZOOMED PLOT --------
ax2 = plt.subplot(1,2,2)

ax2.plot(hours[zoom_start:zoom_end],
         y_true[zoom_start:zoom_end],
         'g-', label='Actual')

ax2.plot(hours[zoom_start:zoom_end],
         y_pred[zoom_start:zoom_end],
         'r-', label='Predicted')

ax2.set_xlabel('Hours')
ax2.set_ylabel('Power Demand')
ax2.set_title('Zoomed View')
ax2.grid(True)

# -------- ARROW (IEEE STYLE) --------
ax1.annotate(
    '',
    xy=(zoom_end, max(y_true)),
    xytext=(zoom_start, max(y_true)),
    arrowprops=dict(arrowstyle='->', lw=1.8)
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# X axis
hours = np.arange(len(y_true))

# ===== SELECT ZOOM REGION (CHANGE THESE) =====
zoom_start = 530
zoom_end   = 570

# ===== FIGURE WITH 2 PANELS =====
fig = plt.figure(figsize=(14,5))

# -------- LEFT: FULL PLOT --------
ax1 = plt.subplot(1,2,1)

ax1.plot(hours, y_true, 'g-', label='Actual')
ax1.plot(hours, y_pred, 'r-', label='Predicted')

ax1.set_xlabel('Hours (Last 30 Days)')
ax1.set_ylabel('Power Demand')
ax1.set_title('Actual vs Predicted (Full Range)')
ax1.legend()
ax1.grid(True)

# Highlight zoom area
ax1.axvspan(zoom_start, zoom_end, color='gray', alpha=0.3)

# -------- RIGHT: ZOOMED PLOT --------
ax2 = plt.subplot(1,2,2)

ax2.plot(hours[zoom_start:zoom_end],
         y_true[zoom_start:zoom_end],
         'g-', label='Actual')

ax2.plot(hours[zoom_start:zoom_end],
         y_pred[zoom_start:zoom_end],
         'r-', label='Predicted')

ax2.set_xlabel('Hours')
ax2.set_ylabel('Power Demand')
ax2.set_title('Zoomed View')
ax2.grid(True)

# -------- ARROW (IEEE STYLE) --------
ax1.annotate(
    '',
    xy=(zoom_end, max(y_true)),
    xytext=(zoom_start, max(y_true)),
    arrowprops=dict(arrowstyle='->', lw=1.8)
)

plt.tight_layout()
plt.show()
